# %% [markdown]
# The following experiments compare the improvement of saving optimizer states after every global model aggregation in different configurations.

# %%
import pickle
import os
import pandas
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# The following figure shows the training results comparsion between our training script and the training script used in KubeML

# %%
# baseline
network = 'vgg11'
epoch = 10
batch_size = 256
lr = 0.01

# get error if n = 4
number_of_workers = 2
K = -1

x = np.arange(0, epoch, 1)
s1 = [9.76934375,9.76890625,13.687,18.20465625,23.1164375,30.6285,41.53721875,45.69934375,51.05990625,52.18371875]
s2 = [17.9095,21.74353125,25.84946875,28.398625,32.753,35.270125,37.73853125,40.33771875,42.12778125,43.1629375]

t1 = [20.286496983,56.241342699,90.159391706,123.727058723,157.716795646,191.720752808,225.73413216,261.645886352,295.728002193,330.278824934]
t2 = [18.449645301,48.292326884,74.872630364,99.651048768,124.748325604,149.92775127,174.399740911,203.462320288,233.821963066,259.817382636]

fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(x, s1, "-bo", label="New")
ax[0].plot(x, s2, "-ro", label="KubeML")
ax[0].set_title('raw data')
ax[0].legend(loc="lower right")
ax[0].set(xlabel='epoch (s)', ylabel='accuracy (%)')


# ax[1].plot(t, (np.divide(s1, s2) - 1)*100, "-b")
# ax[1].set_title('improvement')
# ax[1].set(xlabel='epoch (s)', ylabel='accuracy improvement (%)')

ax[1].plot(x, np.subtract(s1, s2), "-co")
ax[1].set_title('accuracy difference')
ax[1].set(xlabel='epoch (s)', ylabel='accuracy difference (%)')

ax[2].plot(x, t1, "-bo", label="New")
ax[2].plot(x, t2, "-ro", label="KubeML")
ax[2].set_title('latency raw data')
ax[2].legend(loc="lower right")
ax[2].set(xlabel='epoch (s)', ylabel='time (s)')

fig.suptitle(f'netork: {network}, number of functions: {number_of_workers}, batch size: {batch_size}, lr: {lr}, K:{K}')
#fig.savefig("test.png")
plt.show()

# %% [markdown]
# The following experiments compare the improvement of saving optimizer states after every global model aggregation in different configurations.

# %%
# baseline
network = 'vgg11'
epoch = 10
batch_size = 256
lr = 0.01

# get error if n = 4
number_of_workers = 2
K = -1

x = np.arange(0, epoch, 1)
s1 = [9.76934375,9.76890625,13.687,18.20465625,23.1164375,30.6285,41.53721875,45.69934375,51.05990625,52.18371875]
s2 = [9.76628125,9.76759375,12.229625,19.7651875,23.22703125,34.2189375,42.0851875,45.77396875,50.110125,53.83971875]

t1 = [20.286496983,56.241342699,90.159391706,123.727058723,157.716795646,191.720752808,225.73413216,261.645886352,295.728002193,330.278824934]
t2 = [18.83776502,50.325283369,81.796312123,113.639780206,144.766252326,171.806896635,202.941620153,234.269134726,265.52697783,296.770753284]

fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(x, s1, "-bo", label="New")
ax[0].plot(x, s2, "-ro", label="KubeML")
ax[0].set_title('raw data')
ax[0].legend(loc="lower right")
ax[0].set(xlabel='epoch (s)', ylabel='accuracy (%)')


# ax[1].plot(t, (np.divide(s1, s2) - 1)*100, "-b")
# ax[1].set_title('improvement')
# ax[1].set(xlabel='epoch (s)', ylabel='accuracy improvement (%)')

ax[1].plot(x, np.subtract(s1, s2), "-c")
ax[1].set_title('accuracy difference')
ax[1].set(xlabel='epoch (s)', ylabel='accuracy difference (%)')

ax[2].plot(x, t1, "-bo", label="New")
ax[2].plot(x, t2, "-ro", label="KubeML")
ax[2].set_title('latency raw data')
ax[2].legend(loc="lower right")
ax[2].set(xlabel='epoch (s)', ylabel='time (s)')

fig.suptitle(f'netork: {network}, number of functions: {number_of_workers}, batch size: {batch_size}, lr: {lr}, K:{K}')
#fig.savefig("test.png")
plt.show()

# %%
# baseline
network = 'vgg11'
epoch = 30
batch_size = 256
lr = 0.01

# get error if n = 4
number_of_workers = 2
K = -1

x = np.arange(0, epoch, 1)
s1 = [9.76715625,9.76890625,16.0235,23.08109375,31.8760625,39.33459375,45.898375,49.43025,54.51715625,56.1845625,59.46140625,62.040625,65.60190625,67.33665625,66.77421875,68.4585,68.4778125,68.89828125,69.47875,68.4304375,69.467125,69.8555625,70.19878125,70.10571875,69.93828125,71.13934375,71.2905625,70.86634375,71.1738125,70.6708125]
s2 = [9.76759375,9.769125,9.769125,9.769125,16.71434375,22.53771875,28.17875,35.49109375,42.3689375,50.02234375,53.3253125,55.96203125,59.50815625,62.2585625,63.4069375,65.12415625,66.2940625,67.82496875,67.7973125,68.5309375,68.89809375,69.13225,69.914375,69.874875,70.24509375,70.66028125,70.65765625,70.30084375,70.859125,70.677625]

t1 = [20.385195444,55.015927789,89.475756446,123.760277444,160.551197555,197.142571137,232.306873548,269.000589859,305.571491303,339.271455925,373.942284531,410.431198002,447.110598644,483.115681039,520.063037464,555.221093492,592.239561097,628.814083489,665.556084182,699.491067379,733.736972793,767.001323668,801.087008791,834.873763202,871.397170524,908.064558736,944.153390709,978.945131032,1015.381922729,1051.514233856]
t2 = [19.512321688,50.95949007,82.546735833,109.614989453,140.730044531,172.272672574,203.288559925,234.520525228,265.464479912,292.463418379,323.445556878,354.430976281,385.76976591,417.272133611,448.339842472,475.88542674,507.073547085,537.667447462,568.556487101,599.439810451,630.686471306,661.715495547,693.409227973,721.088897965,752.454059588,783.423654517,814.379089271,845.566268127,872.633219407,903.927798359]

fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(x, s1, "-bo", label="New")
ax[0].plot(x, s2, "-ro", label="KubeML")
ax[0].set_title('raw data')
ax[0].legend(loc="lower right")
ax[0].set(xlabel='epoch (s)', ylabel='accuracy (%)')


# ax[1].plot(t, (np.divide(s1, s2) - 1)*100, "-b")
# ax[1].set_title('improvement')
# ax[1].set(xlabel='epoch (s)', ylabel='accuracy improvement (%)')

ax[1].plot(x, np.subtract(s1, s2), "-c")
ax[1].set_title('accuracy difference')
ax[1].set(xlabel='epoch (s)', ylabel='accuracy difference (%)')

ax[2].plot(x, t1, "-bo", label="New")
ax[2].plot(x, t2, "-ro", label="KubeML")
ax[2].set_title('latency raw data')
ax[2].legend(loc="lower right")
ax[2].set(xlabel='epoch (s)', ylabel='time (s)')

fig.suptitle(f'netork: {network}, number of functions: {number_of_workers}, batch size: {batch_size}, lr: {lr}, K:{K}')
#fig.savefig("test.png")
plt.show()

# %%
# number of workers
network = 'vgg11'
epoch = 10
batch_size = 512
lr = 0.01
number_of_workers = 2
K = -1

x = np.arange(0, epoch, 1)
s1 = [9.769125,11.47625,16.2826875,18.5636875,24.09803125,32.21228125,36.98471875,41.77028125,47.6415,49.996]
s2 = [9.769125,12.88778125,20.07021875,22.78746875,27.5035,33.4638125,38.79475,40.33815625,46.69696875,50.2565]

t1 = [20.199164549,53.302057258,86.611397179,119.45769562,152.502083603,186.47572598,219.431421384,252.750976843,285.555809045,320.891766018]
t2 = [18.138539616,49.089649202,79.02136028,109.378264998,135.962835136,165.82774994,196.155586996,222.517864518,253.122940181,283.701338768]
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(x, s1, "-bo", label="New")
ax[0].plot(x, s2, "-ro", label="KubeML")
ax[0].set_title('raw data')
ax[0].legend(loc="lower right")
ax[0].set(xlabel='epoch (s)', ylabel='accuracy (%)')


# ax[1].plot(t, (np.divide(s1, s2) - 1)*100, "-b")
# ax[1].set_title('improvement')
# ax[1].set(xlabel='epoch (s)', ylabel='accuracy improvement (%)')

ax[1].plot(x, np.subtract(s1, s2), "-co")
ax[1].set_title('accuracy difference')
ax[1].set(xlabel='epoch (s)', ylabel='accuracy difference (%)')

ax[2].plot(x, t1, "-bo", label="New")
ax[2].plot(x, t2, "-ro", label="KubeML")
ax[2].set_title('latency raw data')
ax[2].legend(loc="lower right")
ax[2].set(xlabel='epoch (s)', ylabel='time (s)')

fig.suptitle(f'netork: {network}, number of functions: {number_of_workers}, batch size: {batch_size}, lr: {lr}, K:{K}')
#fig.savefig("test.png")
plt.show()

# %%
# different model averaging frequency



network = 'vgg11'
epoch = 10
batch_size = 256
lr = 0.01
number_of_workers = 4

K = [-1, 4]

x = np.arange(0, epoch, 1)
s1_0 = [9.76934375,9.76890625,13.687,18.20465625,23.1164375,30.6285,41.53721875,45.69934375,51.05990625,52.18371875]
s2_0 = [9.76628125,9.76759375,12.229625,19.7651875,23.22703125,34.2189375,42.0851875,45.77396875,50.110125,53.83971875]

t1_0 = [20.286496983,56.241342699,90.159391706,123.727058723,157.716795646,191.720752808,225.73413216,261.645886352,295.728002193,330.278824934]
t2_0 = [18.83776502,50.325283369,81.796312123,113.639780206,144.766252326,171.806896635,202.941620153,234.269134726,265.52697783,296.770753284]

s1_4 = [9.769125,19.5136875,31.24975,40.0370625,49.58475,53.78834375,56.0048125,58.8825,60.53825,60.377625]
s2_4 = [20.746125,27.46859375,32.02728125,37.35009375,40.36228125,45.62628125,47.39265625,47.696375,51.8211875,54.274]


s1_8 = [9.76759375,10.35375,23.348375,38.7043125,45.727,51.26615625,55.03878125,55.85428125,60.81828125,61.7366875]
s2_8 = [9.7665,21.60659375,25.01490625,31.14265625,43.3183125,48.32290625,50.82815625,53.78090625,54.7445,59.17371875]



t1_4 = [310.648838436,639.889964283,963.60909137,1285.868901346,1614.97788759,1944.455733081,2274.347754083,2601.614589929,2926.420141295,3247.704875939]
t2_4 = [241.603894352,494.085475806,747.341597087,1001.28820812,1254.44764414,1506.820099909,1758.924187274,2011.758503377,2264.018094045,2516.632]

t1_8 = [164.164770979,339.441248638,519.795716951,696.787899894,871.247549214,1051.49703734,1233.896717081,1417.627474651,1597.359938949,1781.033167518]
t2_8 = [129.151692318,269.021295093,410.283714184,549.549041044,691.316530943,832.226190043,973.248824361,1114.214898462,1255.311355143,1396.315287137]

fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(x, s1_0, '--bo', label="New: K= -1")
ax[0].plot(x, s2_0, '--ro', label="KubeML: K = -1")
ax[0].plot(x, s1_4, '--b+', label="New: K= 4")
ax[0].plot(x, s2_4, '--r+', label="KubeML: K = 4")
ax[0].plot(x, s1_8, '--b*',label="New: K= 8")
ax[0].plot(x, s2_8, '--r*',label="KubeML: K = 8")
ax[0].set_title('raw data')
ax[0].legend(loc="lower right")
ax[0].set(xlabel='epoch (s)', ylabel='accuracy (%)')


# ax[1].plot(t, (np.divide(s1, s2) - 1)*100, "-b")
# ax[1].set_title('improvement')
# ax[1].set(xlabel='epoch (s)', ylabel='accuracy improvement (%)')

ax[1].plot(x, np.subtract(s1_0, s2_0), "-co", label=" K= -1")
ax[1].plot(x, np.subtract(s1_4, s2_4), "-r+", label=" K= 4")
ax[1].plot(x, np.subtract(s1_8, s2_8), "-b*", label=" K= 8")
ax[1].legend(loc="upper left")

ax[1].set_title('accuracy difference')
ax[1].set(xlabel='epoch (s)', ylabel='accuracy difference (%)')


ax[2].plot(x, t1_0, '--bo', label="New: K= -1")
ax[2].plot(x, t2_0, '--ro', label="KubeML: K = -1")
ax[2].plot(x, t1_4, '--b+', label="New: K= 4")
ax[2].plot(x, t2_4, '--r+', label="KubeML: K = 4")
ax[2].plot(x, t1_8, '--b*',label="New: K= 8")
ax[2].plot(x, t2_8, '--r*',label="KubeML: K = 8")
ax[2].set_title('raw latency data')
ax[2].legend(loc="upper left")
ax[2].set(xlabel='epoch (s)', ylabel='time (s)')

fig.suptitle(f'netork: {network}, number of functions: {number_of_workers}, batch size: {batch_size}, lr: {lr}, K:{K}')
#fig.savefig("test.png")
plt.show()
