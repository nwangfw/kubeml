# %%
import pickle
import os
import pandas
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# The following figure shows the training results comparsion between our training script and the training script used in KubeML

# %%
network = 'resnet34'
epoch = 10
batch_size = 256
lr = 0.01
number_of_workers = 4
K = -1

x = np.arange(0, epoch, 1)
s1 = [9.7661875,24.653,42.478875,46.7841875,49.4056875,51.852375,53.927375,55.77325,57.213,58.769]
s2 = [13.9035,20.986625,27.4246875,31.821125,35.354375,38.602,39.727,40.7774375,42.3034375,44.072875]

t1 = [11.959919394,25.816882186,36.544728843,47.176091881,58.880284294,70.102311491,80.813144942,92.941085771,104.008004296,115.184130373]
t2 = [12.050402954,22.441538333,33.247331146,43.965857949,54.456474614,65.553504149,76.643307103,88.349501504,99.722269067,110.771643385]

fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(x, s1, "-bo", label="New")
ax[0].plot(x, s2, "-ro", label="KubeML")
ax[0].set_title('raw data')
ax[0].legend(loc="lower right")
ax[0].set(xlabel='epoch (s)', ylabel='accuracy (%)')


# ax[1].plot(t, (np.divide(s1, s2) - 1)*100, "-b")
# ax[1].set_title('improvement')
# ax[1].set(xlabel='epoch (s)', ylabel='accuracy improvement (%)')

ax[1].plot(x, np.subtract(s1, s2), "-co")
ax[1].set_title('accuracy difference')
ax[1].set(xlabel='epoch (s)', ylabel='accuracy difference (%)')

ax[2].plot(x, t1, "-bo", label="New")
ax[2].plot(x, t2, "-ro", label="KubeML")
ax[2].set_title('latency raw data')
ax[2].legend(loc="lower right")
ax[2].set(xlabel='epoch (s)', ylabel='time (s)')

fig.suptitle(f'netork: {network}, number of functions: {number_of_workers}, batch size: {batch_size}, lr: {lr}, K:{K}')
#fig.savefig("test.png")
plt.show()

# %% [markdown]
# The following experiments compare the improvement of saving optimizer states after every global model aggregation in different configurations.

# %%
network = 'resnet34'
epoch = 10
batch_size = 256
lr = 0.01
number_of_workers = 4
K = -1

x = np.arange(0, epoch, 1)
s1 = [9.7661875,24.653,42.478875,46.7841875,49.4056875,51.852375,53.927375,55.77325,57.213,58.769]
s2 = [9.8206875,30.206625,40.784625,45.4266875,47.549875,50.235625,51.61,52.9033125,54.53625,55.7415625]

t1 = [11.959919394,25.816882186,36.544728843,47.176091881,58.880284294,70.102311491,80.813144942,92.941085771,104.008004296,115.184130373]
t2 = [12.278357471,22.814520808,34.455620675,44.483074686,54.746753919,66.388973963,76.845937447,87.427516892,98.283126962,109.297304076]

fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(x, s1, "-bo", label="New")
ax[0].plot(x, s2, "-ro", label="Kubeml")
ax[0].set_title('raw data')
ax[0].legend(loc="lower right")
ax[0].set(xlabel='epoch (s)', ylabel='accuracy (%)')


# ax[1].plot(t, (np.divide(s1, s2) - 1)*100, "-b")
# ax[1].set_title('improvement')
# ax[1].set(xlabel='epoch (s)', ylabel='accuracy improvement (%)')

ax[1].plot(x, np.subtract(s1, s2), "-co")
ax[1].set_title('accuracy difference')
ax[1].set(xlabel='epoch (s)', ylabel='accuracy difference (%)')

ax[2].plot(x, t1, "-bo", label="New")
ax[2].plot(x, t2, "-ro", label="Kubeml")
ax[2].set_title('latency raw data')
ax[2].legend(loc="lower right")
ax[2].set(xlabel='epoch (s)', ylabel='time (s)')

fig.suptitle(f'netork: {network}, number of functions: {number_of_workers}, batch size: {batch_size}, lr: {lr}, K:{K}')
#fig.savefig("test.png")
plt.show()

# %%
network = 'resnet34'
epoch = 30
batch_size = 256
lr = 0.01
number_of_workers = 6
K = -1

x = np.arange(0, epoch, 1)
s1 = [9.95625,17.775089285714287,32.77875,37.79883928571429,42.45035714285715,45.47160714285714,46.669464285714284,47.50544642857143,50.19866071428571,51.343125,52.39098214285714,52.90892857142858,54.409017857142864,55.674196428571435,55.94089285714286,57.199910714285714,57.89776785714287,58.68607142857143,59.42116071428572,60.247142857142855,60.780625,61.079642857142865,61.67517857142858,62.34767857142857,62.94473214285715,63.59017857142858,64.236875,64.29026785714285,64.45035714285713,65.00008928571427]
s2 = [9.190267857142857,17.54678571428571,32.05178571428571,37.57142857142857,41.933035714285715,43.49910714285715,46.02660714285714,47.05017857142857,48.24883928571428,49.028749999999995,49.54473214285715,50.86116071428572,52.089732142857144,53.64312499999999,54.46017857142857,53.818303571428565,55.72660714285715,56.15446428571428,56.54955357142857,58.09401785714285,57.88714285714286,58.464107142857145,59.42866071428572,60.0336607142857,60.72955357142857,60.270892857142854,61.26830357142857,60.73598214285715,61.903660714285714,62.089196428571434]

t1 = [10.736567535,22.951953104,33.057392502,46.088896962,55.550351719,66.439453792,77.695460631,88.561372371,99.26010846,110.046779206,121.007221977,131.953490215,142.325592959,153.362333572,164.307067565,175.200152925,186.128016786,196.63541205,207.533751758,218.403177689,229.599506459,240.320938287,251.658167215,262.535883855,273.532308132,284.275233414,294.818566363,305.994015699,316.826923742,327.845526691]
t2 = [10.518932749,20.318189071,31.124547859,41.528257434,51.746763656,62.002876703,72.338674641,82.513940792,93.069335756,103.686572407,114.447429572,124.170066189,134.508765514,145.042819383,155.677751331,165.863328447,176.579676452,187.256923387,197.700752515,208.431038639,219.066058722,229.663297963,240.49069985,250.699235807,260.755769601,271.228475388,281.810061032,292.378071334,302.974939012,313.818269506]
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(x, s1, "-bo", label="New")
ax[0].plot(x, s2, "-ro", label="KubeML")
ax[0].set_title('raw data')
ax[0].legend(loc="lower right")
ax[0].set(xlabel='epoch (s)', ylabel='accuracy (%)')


# ax[1].plot(t, (np.divide(s1, s2) - 1)*100, "-b")
# ax[1].set_title('improvement')
# ax[1].set(xlabel='epoch (s)', ylabel='accuracy improvement (%)')

ax[1].plot(x, np.subtract(s1, s2), "-c")
ax[1].set_title('accuracy difference')
ax[1].set(xlabel='epoch (s)', ylabel='accuracy difference (%)')


ax[2].plot(x, t1, "-bo", label="New")
ax[2].plot(x, t2, "-ro", label="KubeML")
ax[2].set_title('latency raw data')
ax[2].legend(loc="lower right")
ax[2].set(xlabel='epoch (s)', ylabel='time (s)')

fig.suptitle(f'netork: {network}, number of functions: {number_of_workers}, batch size: {batch_size}, lr: {lr}, K:{K}')
#fig.savefig("test.png")
plt.show()

# %%
# number of workers
network = 'resnet34'
epoch = 30
batch_size = 512
lr = 0.01
number_of_workers = 4
K = -1

x = np.arange(0, epoch, 1)
s1 = [10.35525,29.542,38.75625,43.5251875,45.8556875,48.0869375,50.46225,51.386625,52.6389375,53.9485,56.2290625,55.7396875,57.55525,58.7805,59.1268125,60.0798125,60.8721875,61.629625,62.5615,63.455,63.431375,64.4591875,64.402625,64.9294375,64.8923125,65.296,65.8334375,65.6995625,66.705875,66.820875]
s2 = [11.66925,29.5418125,37.4418125,41.753,43.9814375,46.13575,47.2349375,49.2489375,49.7255,51.964,52.6183125,53.5606875,54.53125,54.1104375,55.6594375,56.8755,56.508375,57.513125,58.8325,58.80425,59.7718125,60.021875,60.6845625,61.137375,60.846375,62.0453125,62.5715,62.7423125,63.2326875,63.9701875]

t1 = [11.340786378,23.752319246,36.106946987,46.990648081,57.750740624,68.572756249,79.147204582,90.05767178,102.038104676,113.685562047,124.648859129,135.699853956,146.764786373,157.364767129,168.217435263,180.342303076,190.433834447,201.670358027,212.963172181,222.840079853,233.986858334,244.83785429,255.830103287,267.432757861,278.35409748,289.191951916,300.199225657,310.385710652,321.67519599,331.822211169]
t2 = [11.582661335,21.669510208,31.927022911999998,42.400806474,53.089629037,63.172346915,72.782486371,83.186091487,93.451965067,103.977574509,114.508932994,124.421230762,135.427996814,145.523934341,155.475488366,165.708410779,176.35859826,186.452022528,196.839928024,207.649244919,218.297136741,228.890594248,238.377992996,249.166670126,259.871611818,270.324146111,280.879273934,290.4184728,300.598342732,310.91429356]
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(x, s1, "-bo", label="New")
ax[0].plot(x, s2, "-ro", label="KubeML")
ax[0].set_title('raw data')
ax[0].legend(loc="lower right")
ax[0].set(xlabel='epoch (s)', ylabel='accuracy (%)')


# ax[1].plot(t, (np.divide(s1, s2) - 1)*100, "-b")
# ax[1].set_title('improvement')
# ax[1].set(xlabel='epoch (s)', ylabel='accuracy improvement (%)')

ax[1].plot(x, np.subtract(s1, s2), "-co")
ax[1].set_title('performance difference')
ax[1].set(xlabel='epoch (s)', ylabel='accuracy difference (%)')

ax[2].plot(x, t1, "-bo", label="New")
ax[2].plot(x, t2, "-ro", label="KubeML")
ax[2].set_title('latency raw data')
ax[2].legend(loc="lower right")
ax[2].set(xlabel='epoch (s)', ylabel='time (s)')

fig.suptitle(f'netork: {network}, number of functions: {number_of_workers}, batch size: {batch_size}, lr: {lr}, K:{K}')
#fig.savefig("test.png")
plt.show()

# %%
# different model averaging frequency



network = 'resnet34'
epoch = 10
batch_size = 256
lr = 0.01
number_of_workers = 4

K = [-1, 4, 8]

x = np.arange(0, epoch, 1)
s1_0 = [9.7661875,24.653,42.478875,46.7841875,49.4056875,51.852375,53.927375,55.77325,57.213,58.769]
s2_0 = [9.8206875,30.206625,40.784625,45.4266875,47.549875,50.235625,51.61,52.9033125,54.53625,55.7415625]


s1_4 = [36.5645,44.435875,48.21025,50.8066875,52.5133125,53.6770625,55.8450625,57.3041875,57.8046875,59.061375]
s2_4 = [30.0488125,36.8568125,40.7434375,42.9741875,45.2929375,46.2345625,47.372625,49.0871875,49.86125,50.519]

s1_8 = [33.085,41.9705625,46.4844375,49.4728125,50.3298125,52.912125,54.2605,55.1339375,57.54425,59.4979375]
s2_8 = [31.0513125,37.512875,43.312875,45.8325625,46.8548125,48.48425,49.244875,50.9746875,52.0778125,53.2415]




t1_0 = [11.959919394,25.816882186,36.544728843,47.176091881,58.880284294,70.102311491,80.813144942,92.941085771,104.008004296,115.184130373]
t2_0 = [12.278357471,22.814520808,34.455620675,44.483074686,54.746753919,66.388973963,76.845937447,87.427516892,98.283126962,109.297304076]

t1_4 = [45.829988645,93.177893034,144.032174006,194.375339654,244.874603226,296.734199498,348.979255741,395.933711795,442.387493192,488.482318795]
t2_4 = [40.407499694,80.877312778,121.369765954,161.792969247,202.435288016,242.494729584,283.235538119,323.4061391,364.458709865,404.518404613]


t1_8 = [28.210328813,57.472194247,94.617341696,124.399317757,152.176712432,186.269677698,214.013534492,247.377653116,276.345579074,309.479081593]
t2_8 = [25.180034919,54.112809764,82.674151806,107.918827397,133.039659188,157.606710935,182.74740402,211.505862249,244.41669539,269.4679944]

fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(x, s1_0, '--bo', label="New: K= -1")
ax[0].plot(x, s2_0, '--ro', label="KubeML: K = -1")
ax[0].plot(x, s1_4, '--b+', label="New: K= 4")
ax[0].plot(x, s2_4, '--r+', label="KubeML: K = 4")
ax[0].plot(x, s1_8, '--b*',label="New: K= 8")
ax[0].plot(x, s2_8, '--r*',label="KubeML: K = 8")
ax[0].set_title('raw data')
ax[0].legend(loc="lower right")
ax[0].set(xlabel='epoch (s)', ylabel='accuracy (%)')


# ax[1].plot(t, (np.divide(s1, s2) - 1)*100, "-b")
# ax[1].set_title('improvement')
# ax[1].set(xlabel='epoch (s)', ylabel='accuracy improvement (%)')

ax[1].plot(x, np.subtract(s1_0, s2_0), "-co", label=" K= -1")
ax[1].plot(x, np.subtract(s1_4, s2_4), "-r+", label=" K= 4")
ax[1].plot(x, np.subtract(s1_8, s2_8), "-b*", label=" K= 8")

ax[1].set_title('accuracy difference')
ax[1].set(xlabel='epoch (s)', ylabel='accuracy difference (%)')
ax[1].legend(loc="upper left")


ax[2].plot(x, t1_0, '--bo', label="New: K= -1")
ax[2].plot(x, t2_0, '--ro', label="KubeML: K = -1")
ax[2].plot(x, t1_4, '--b+', label="New: K= 4")
ax[2].plot(x, t2_4, '--r+', label="KubeML: K = 4")
ax[2].plot(x, t1_8, '--b*',label="New: K= 8")
ax[2].plot(x, t2_8, '--r*',label="KubeML: K = 8")
ax[2].set_title('raw latency data')
ax[2].legend(loc="upper left")
ax[2].set(xlabel='epoch (s)', ylabel='time (s)')

fig.suptitle(f'netork: {network}, number of functions: {number_of_workers}, batch size: {batch_size}, lr: {lr}, K:{K}')
#fig.savefig("test.png")
plt.show()
