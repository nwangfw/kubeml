# %% [markdown]
# The following experiments compare the improvement of saving optimizer states after every global model aggregation in different configurations.

# %%
import pickle
import os
import pandas
import matplotlib.pyplot as plt
import numpy as np

# %%
network = 'resnet34'
epoch = 10
batch_size = 256
lr = 0.01
number_of_workers = 4
K = -1

x = np.arange(0, epoch, 1)
s1 = [1.1730625,4.6636875,12.1385,15.3114375,17.9350625,19.6015,22.324375,23.5805,25.1351875,26.101]
s2 = [0.978125,4.1333125,11.515,15.548625,17.241875,19.3135,21.33075,22.75975,23.9796875,25.249625]

t1 = [11.640305527,24.881179459,35.686278535,47.356310753,58.545956264,68.749326314,79.690219858,91.488132628,102.688928464,113.864994442]
t2 = [11.640139371,22.094611962,33.660325016,44.230293789,55.170151166,66.146097579,77.261697906,87.791614864,99.03039903,109.803416467]

fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(x, s1, "-b", label="Our")
ax[0].plot(x, s2, "-r", label="Kubeml")
ax[0].set_title('raw data')
ax[0].legend(loc="lower right")
ax[0].set(xlabel='epoch (s)', ylabel='accuracy (%)')


# ax[1].plot(t, (np.divide(s1, s2) - 1)*100, "-b")
# ax[1].set_title('improvement')
# ax[1].set(xlabel='epoch (s)', ylabel='accuracy improvement (%)')

ax[1].plot(x, np.subtract(s1, s2), "-c")
ax[1].set_title('accuracy difference')
ax[1].set(xlabel='epoch (s)', ylabel='accuracy difference (%)')

ax[2].plot(x, t1, "-b", label="Our")
ax[2].plot(x, t2, "-r", label="Kubeml")
ax[2].set_title('latency raw data')
ax[2].legend(loc="lower right")
ax[2].set(xlabel='epoch (s)', ylabel='time (s)')

fig.suptitle(f'netork: {network}, number of functions: {number_of_workers}, batch size: {batch_size}, lr: {lr}, K:{K}')
#fig.savefig("test.png")
plt.show()

# %%
network = 'resnet34'
epoch = 10
batch_size = 256
lr = 0.01
number_of_workers = 6
K = -1

x = np.arange(0, epoch, 1)
s1 = [0.9307142857142857,2.3744642857142857,8.890982142857142,12.19526785714286,15.391785714285716,16.861160714285717,18.11044642857143,19.17919642857143,20.327142857142857,20.99732142857143]
s2 = [0.9307142857142857,2.4475892857142854,8.597232142857143,11.209821428571429,13.318125,15.49232142857143,17.17080357142857,18.063482142857143,19.08455357142857,20.084910714285716]

t1 = [10.882106043,23.234839012,34.290059596,45.874134851,57.50111492,67.004342029,77.57399496,88.510721647,98.774517407,109.376922692]
t2 = [10.353307781,20.267244278,29.95857821,40.110943535,50.105995657,60.450340219,70.713178127,80.735234848,90.553800274,100.582044413]
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(x, s1, "-b", label="after")
ax[0].plot(x, s2, "-r", label="before")
ax[0].set_title('raw data')
ax[0].legend(loc="lower right")
ax[0].set(xlabel='epoch (s)', ylabel='accuracy (%)')


# ax[1].plot(t, (np.divide(s1, s2) - 1)*100, "-b")
# ax[1].set_title('improvement')
# ax[1].set(xlabel='epoch (s)', ylabel='accuracy improvement (%)')

ax[1].plot(x, np.subtract(s1, s2), "-c")
ax[1].set_title('accuracy difference')
ax[1].set(xlabel='epoch (s)', ylabel='accuracy difference (%)')


ax[2].plot(x, t1, "-b", label="after")
ax[2].plot(x, t2, "-r", label="before")
ax[2].set_title('latency raw data')
ax[2].legend(loc="lower right")
ax[2].set(xlabel='epoch (s)', ylabel='time (s)')

fig.suptitle(f'netork: {network}, number of functions: {number_of_workers}, batch size: {batch_size}, lr: {lr}, K:{K}')
#fig.savefig("test.png")
plt.show()

# %%
# number of workers
network = 'resnet34'
epoch = 10
batch_size = 512
lr = 0.01
number_of_workers = 4
K = -1

x = np.arange(0, epoch, 1)
s1 = [1.0059375,5.6460625,10.5701875,13.1065,15.2695625,17.162875,18.332125,19.9510625,21.365125,22.6583125]
s2 = [1.054625,4.9435625,8.5080625,11.1636875,13.27125,15.266125,16.6888125,18.13375,18.78025,19.585375]

t1 = [10.839267569,23.148190403,35.739847435,45.607668942,55.934642032,66.703522991,77.081827731,88.147308164,99.951350126,110.147245443]
t2 = [11.483405269,21.936615983,32.255054796,41.809585885,52.903179651,62.698469799,74.021635855,83.742141624,94.021846222,103.923685106]
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(x, s1, "-b", label="after")
ax[0].plot(x, s2, "-r", label="before")
ax[0].set_title('raw data')
ax[0].legend(loc="lower right")
ax[0].set(xlabel='epoch (s)', ylabel='accuracy (%)')


# ax[1].plot(t, (np.divide(s1, s2) - 1)*100, "-b")
# ax[1].set_title('improvement')
# ax[1].set(xlabel='epoch (s)', ylabel='accuracy improvement (%)')

ax[1].plot(x, np.subtract(s1, s2), "-c")
ax[1].set_title('performance difference')
ax[1].set(xlabel='epoch (s)', ylabel='accuracy difference (%)')

ax[2].plot(x, t1, "-b", label="after")
ax[2].plot(x, t2, "-r", label="before")
ax[2].set_title('latency raw data')
ax[2].legend(loc="lower right")
ax[2].set(xlabel='epoch (s)', ylabel='time (s)')

fig.suptitle(f'netork: {network}, number of functions: {number_of_workers}, batch size: {batch_size}, lr: {lr}, K:{K}')
#fig.savefig("test.png")
plt.show()

# %%
network = 'resnet34'
epoch = 10
batch_size = 256
lr = 0.01
number_of_workers = 4

K = [-1, 4, 8]

x = np.arange(0, epoch, 1)


s1_0 = [1.1730625,4.6636875,12.1385,15.3114375,17.9350625,19.6015,22.324375,23.5805,25.1351875,26.101]
s2_0 = [0.978125,4.1333125,11.515,15.548625,17.241875,19.3135,21.33075,22.75975,23.9796875,25.249625]


s1_4 = [6.77425,11.782375,16.340625,19.0583125,21.0490625,23.1890625,23.7400625,24.5969375,26.2643125,28.3379375]
s2_4 = [5.365875,10.9281875,13.8448125,15.4888125,17.1053125,18.3098125,19.546625,21.079125,21.59525,22.81025]

s1_8 = [33.085,41.9705625,46.4844375,49.4728125,50.3298125,52.912125,54.2605,55.1339375,57.54425,59.4979375]
s2_8 = [31.0513125,37.512875,43.312875,45.8325625,46.8548125,48.48425,49.244875,50.9746875,52.0778125,53.2415]



t1_0 = [11.640305527,24.881179459,35.686278535,47.356310753,58.545956264,68.749326314,79.690219858,91.488132628,102.688928464,113.864994442]
t2_0 = [11.640139371,22.094611962,33.660325016,44.230293789,55.170151166,66.146097579,77.261697906,87.791614864,99.03039903,109.803416467]

t1_4 = [28.141867411,60.534535923,87.805988863,116.891156639,145.707825245,178.57825733,207.640013918,236.225628151,271.09345772,298.885086271]
t2_4 = [24.933923452,52.652764284,78.110977387,102.564736979,127.254747824,151.991464014,180.631699089,209.60039179,234.605779459,259.122588015]


t1_8 = [28.210328813,57.472194247,94.617341696,124.399317757,152.176712432,186.269677698,214.013534492,247.377653116,276.345579074,309.479081593]
t2_8 = [25.180034919,54.112809764,82.674151806,107.918827397,133.039659188,157.606710935,182.74740402,211.505862249,244.41669539,269.4679944]

fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(x, s1_0, '--bo', label="after: K= -1")
ax[0].plot(x, s2_0, '--ro', label="before: K = -1")
ax[0].plot(x, s1_4, '--b+', label="after: K= 4")
ax[0].plot(x, s2_4, '--r+', label="before: K = 4")
ax[0].plot(x, s1_8, '--b*',label="after: K= 8")
ax[0].plot(x, s2_8, '--r*',label="before: K = 8")
ax[0].set_title('raw data')
ax[0].legend(loc="lower right")
ax[0].set(xlabel='epoch (s)', ylabel='accuracy (%)')


# ax[1].plot(t, (np.divide(s1, s2) - 1)*100, "-b")
# ax[1].set_title('improvement')
# ax[1].set(xlabel='epoch (s)', ylabel='accuracy improvement (%)')

ax[1].plot(x, np.subtract(s1_0, s2_0), "-co", label=" K= -1")
ax[1].plot(x, np.subtract(s1_4, s2_4), "-r+", label=" K= 4")
ax[1].plot(x, np.subtract(s1_8, s2_8), "-b*", label=" K= 8")

ax[1].set_title('accuracy difference')
ax[1].set(xlabel='epoch (s)', ylabel='accuracy difference (%)')
ax[1].legend(loc="upper left")


ax[2].plot(x, t1_0, '--bo', label="after: K= -1")
ax[2].plot(x, t2_0, '--ro', label="before: K = -1")
ax[2].plot(x, t1_4, '--b+', label="after: K= 4")
ax[2].plot(x, t2_4, '--r+', label="before: K = 4")
ax[2].plot(x, t1_8, '--b*',label="after: K= 8")
ax[2].plot(x, t2_8, '--r*',label="before: K = 8")
ax[2].set_title('raw latency data')
ax[2].legend(loc="upper left")
ax[2].set(xlabel='epoch (s)', ylabel='time (s)')

fig.suptitle(f'netork: {network}, number of functions: {number_of_workers}, batch size: {batch_size}, lr: {lr}, K:{K}')
#fig.savefig("test.png")
plt.show()
